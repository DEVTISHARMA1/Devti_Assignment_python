# %%
df['Brand'].value_counts().plot(kind='bar', title='Brand Distribution')
plt.xlabel('Brand')
plt.ylabel('Number of Models')
plt.show()

# %%
df['rating'].plot(kind='hist', bins=10, title='Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
top_brands = df['Brand'].value_counts().nlargest(10)
top_brands.plot(kind='bar', title='Top 10 Brands')
plt.xlabel('Brand')
plt.ylabel('Number of Models')
plt.show()

# %%
df['processor'].value_counts().nlargest(10).plot(kind='bar', title='Top 10 Processor Distribution')
plt.xlabel('Processor')
plt.ylabel('Number of Models')
plt.show()

# %%
df['warranty'].value_counts().nlargest(10).plot(kind='bar', title='Top 10 Warranty Period Distribution')
plt.xlabel('Warranty')
plt.ylabel('Number of Models')
plt.show()

# %%
sns.regplot(x='battery_capacity', y='price', data=df)
plt.title('Price vs. Battery Capacity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sns.regplot(x='battery_capacity', y='price', data=df)
#       2 plt.title('Price vs. Battery Capacity')
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns
